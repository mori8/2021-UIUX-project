# %% [markdown]
# <a href="https://colab.research.google.com/github/mori8/2021-UIUX-project/blob/main/%5BYouTube%5DPyTorch_Lecture_by_Sung_Kim_ch_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch.autograd import Variable

x_data = Variable(torch.Tensor([[1.0], [2.0], [3.0]]))
y_data = Variable(torch.Tensor([[2.0], [4.0], [6.0]]))

# %%
class Model(torch.nn.Module):
  def __init__(self):
    super(Model, self).__init__()
    self.linear = torch.nn.Linear(1, 1) # one in and one out
  
  def forward(self, x):
    y_pred = self.linear(x)
    return y_pred

# %%
model = Model()

criterion = torch.nn.MSELoss(size_average=False)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# Training loop
for epoch in range(500):
  # Forward pass
  y_pred = model(x_data)

  loss = criterion(y_pred, y_data)
  print(epoch, loss.sum().item())

  # Zero gradients, perform a backward pass, and update the weights
  optimizer.zero_grad() # 이전 그레이디언트 초기화
  loss.backward()   # 그레이디언트 계산
  #  ==> w.data = w.data - 0.01 * w.grad.data
  optimizer.step()  # 그레이디언트 업데이트
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# 0 55.85736846923828
# 1 25.270614624023438
# 2 11.648445129394531
# 3 5.578513145446777
# 4 2.8707053661346436
# 5 1.659698724746704
# 6 1.1151072978973389
# 7 0.8672634363174438
# 8 0.7516007423400879
# 9 0.6948577761650085
# 10 0.6644198894500732
# 11 0.6457666754722595
# 12 0.6324328780174255
# 13 0.6215395331382751
# 14 0.6118037700653076
# 15 0.6026539206504822
# 16 0.5938336253166199
# 17 0.5852283835411072
# 18 0.5767860412597656
# 19 0.5684826374053955
# 20 0.5603067874908447
# 21 0.5522509813308716
# 22 0.5443132519721985
# 23 0.5364900827407837
# 24 0.5287798047065735
# 25 0.5211798548698425
# 26 0.5136900544166565
# 27 0.5063071846961975
# 28 0.49903053045272827
# 29 0.49185910820961
# 30 0.48479005694389343
# 31 0.477822870016098
# 32 0.47095581889152527
# ...

# %%
# After training
hour_var = Variable(torch.Tensor([[4.0]]))
print("predict (after training)", 4, model.forward(hour_var).item())
# Out:
# predict (after training) 4 7.973143100738525
